# %% [markdown]
# # Adult Income Prediction — Day 5 Final Project
#
# This notebook runs the final production workflow: artifact loading, untouched-test validation, error analysis, calibration, learning curve, feature interpretation, inference smoke testing, and report generation.
#
# **Important:** place the exact Day 4 `final_model.joblib` beside this notebook/script before running.

# %%
# Run the complete Day 5 pipeline.
# The script writes all outputs to adult_income_day5_outputs/.
# %run Task_5_Adult_Income_Final.py

# %% [markdown]
# ## Production inference
#
# The saved pipeline is used directly; preprocessing is not repeated manually.

# %%
import pandas as pd
from inference import predict_income

new_data = pd.DataFrame([{
    'age': 39,
    'workclass': 'Private',
    'fnlwgt': 77516,
    'education': 'Bachelors',
    'education-num': 13,
    'marital-status': 'Never-married',
    'occupation': 'Exec-managerial',
    'relationship': 'Not-in-family',
    'race': 'White',
    'sex': 'Male',
    'capital-gain': 0,
    'capital-loss': 0,
    'hours-per-week': 40,
    'native-country': 'United-States',
}])

predict_income(new_data)
